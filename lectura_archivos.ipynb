# %%
import json

# Abrir el archivo JSON en modo lectura
with open('ejemplo.json', 'r') as archivo:
    # Cargar el contenido del archivo a una variable de Python
    datos = json.load(archivo)

# Ahora puedes acceder a los datos como un diccionario o lista
print(datos)

# %%
for i in datos['toppings']:
    print(i)

# %%
datos['cliente']['nombre']

# %%
datos['lista_clientes'][0:3]

# %%
datos['lista_clientes'][0]['nombre']
