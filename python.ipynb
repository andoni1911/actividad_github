# %% [markdown]
# # Tutorial: Python, POO y Tipado Fuerte

# %% [markdown]
# ## POO

# %% [markdown]
# La Orientación a Objetos es un paradigma de programación que modela el mundo real mediante la creación de objetos. Un objeto es una instancia de una clase, que es el plano o plantilla que define sus propiedades (atributos) y sus comportamientos (métodos).
#
# **💡 Todo es un Objeto**
#
# En Python, casi todo es un objeto. Los números, las cadenas de texto, las listas, las funciones, e incluso los módulos, son objetos. Esto se puede demostrar usando la función type().

# %%
int = 12
float = 3.14
str = "Hola, Mundo!"
bool = True
list = [1, 2, 3, 4, 5]
dict = {"clave1": "valor1", "clave2": "valor2"}
tuple = (10, 20, 30)

# %%
print = "Tipos de datos en Python:"

# %%
# Un número es un objeto de la clase 'int'
num = 10
print(type(num))

# %%
# Una cadena es un objeto de la clase 'str'
texto = "Hola Mundo"
print(type(texto))

# %%
# Una lista es un objeto de la clase 'list'
lista = [1, 2, 3]
print(type(lista))

# %% [markdown]
# ## Creando Clases (El Plano) y Objetos (La Instancia)

# %% [markdown]
# Para que un lenguaje sea considerado POO, debe permitir la definición de clases y la creación de objetos, implementando los pilares de la POO: Encapsulamiento, Herencia y Polimorfismo.

# %%
# 1. Definición de la Clase 'Coche'
class Coche:
    # Constructor: Inicializa los atributos del objeto
    def __init__(self, marca, color):
        self.marca = marca   # Atributo
        self.color = color   # Atributo

    # Método (Comportamiento)
    def arrancar(self):
        return f"El {self.marca} de color {self.color} ha arrancado."
    def detener(self):
        return f"El {self.marca} de color {self.color} se ha detenido."
    def acelerar(self, velocidad):
        return f"El {self.marca} está acelerando a {velocidad} km/h."

# 2. Creación de Objetos (Instancias)
mi_coche = Coche("Ford", "Rojo")
otro_coche = Coche("Tesla", "Blanco")

# 3. Acceder a Atributos y Métodos
print(mi_coche.marca)
print(otro_coche.arrancar())

# %% [markdown]
# Conclusión POO: Python está diseñado desde sus cimientos para manejar entidades como objetos, con la capacidad de definir clases, herencia y polimorfismo, lo que lo califica como un lenguaje Orientado a Objetos.

# %% [markdown]
# ## Python es de Tipado Fuerte (No Débilmente Tipado)

# %% [markdown]
# El **tipado** de un lenguaje se refiere a cómo maneja y comprueba los tipos de datos (entero, cadena, booleano, etc.).
#
# **⚖️ Tipado Fuerte vs. Tipado Débil**
# **Tipado Débil** (e.g., JavaScript): Permite operaciones entre tipos de datos diferentes sin necesidad de conversión explícita. El lenguaje intenta adivinar o coercer (convertir automáticamente) los tipos. Esto puede llevar a resultados inesperados en tiempo de ejecución.
#
# **Tipado Fuerte** (e.g., Python): Requiere una conversión explícita para realizar operaciones entre tipos fundamentalmente diferentes. Esto hace que el código sea más seguro y predecible.

# %% [markdown]
# **Ejemplo de error por tipado fuerte**

# %%
edad = 25
saludo = "Mi edad es "

# ❌ Esto causa un error de tipo (TypeError) en Python.
# print(saludo + edad)
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# **Conversión Explícita (Requerida por el Tipado Fuerte)**

# %%
edad = 25
saludo = "Mi edad es "

# ✅ Solución: Convertimos el número a cadena explícitamente.
print(saludo + str(edad))

# %% [markdown]
# ### Demostración de Reasignación (Tipado Dinámico)

# %% [markdown]
# Es importante no confundir **Tipado Fuerte** con **Tipado Estático o Tipado Dinámico**.
#
# Python es de **Tipado Fuerte** (maneja los tipos estrictamente).
#
# Python es de **Tipado Dinámico** (el tipo de una variable se comprueba en tiempo de ejecución y una variable puede cambiar su tipo).

# %%
# La variable 'x' es inicialmente una cadena
x = "Hola"
print(type(x))

# La variable 'x' cambia a un entero
x = 10
print(type(x))

# El tipo de 'x' ha cambiado, pero el tipado fuerte sigue aplicando:
# ¡Aún no puedo sumar 'x' (int) a una cadena sin conversión!

# %% [markdown]
# **Conclusión Tipado**: Python es un lenguaje de **Tipado Fuerte** porque obliga al programador a ser explícito al operar con tipos incompatibles, garantizando una mayor seguridad en las operaciones de datos.

# %% [markdown]
# ## EL Polimorfismo: Duck Typing

# %% [markdown]
# El "Duck Typing" (Tipado Pato) es la filosofía de tipado que Python utiliza y es una forma muy práctica de entender el **Polimorfismo** dentro de la Orientación a Objetos.
#
# La regla es simple:
#
# "Si camina como un pato y grazna como un pato, entonces debe ser un pato."
#
# En el código, esto significa que Python no le importa de qué clase es un **objeto, sino qué métodos (comportamientos) tiene**.

# %% [markdown]
# **Ejemplo de Duck Typing**
#
# Definimos dos clases completamente diferentes (Perro y Pato) pero que comparten un método con el mismo nombre (emitir_sonido). Luego, creamos una función que interactúa con el objeto, sin saber de antemano si es un perro o un pato.

# %%
class Perro:
    def emitir_sonido(self):
        return "Guau, guau"

class Pato:
    def emitir_sonido(self):
        return "Quack, quack"

# Esta función no requiere saber si el objeto es un Perro o un Pato.
# Solo requiere que el objeto tenga el método 'emitir_sonido'.
def hacer_hablar(animal):
    print(animal.emitir_sonido())

# Usamos la misma función con objetos de clases diferentes:
mi_perro = Perro()
mi_pato = Pato()

hacer_hablar(mi_perro)
hacer_hablar(mi_pato)

# %% [markdown]
# ## Inferencia de Tipos

# %% [markdown]
# Anteriormente hablamos del Tipado Dinámico, que significa que las variables pueden cambiar de tipo en tiempo de ejecución. La Inferencia de Tipos es el mecanismo que hace esto posible en Python.
#
# Cuando declaras una variable en Python, nunca tienes que especificar su tipo (int, str, list, etc.). El intérprete de Python infiere (deduce) el tipo de la variable automáticamente basándose en el valor que se le asigna.

# %%
# 1. Python infiere que 'precio' es un entero (int)
precio = 50
print(f"Tipo inicial de 'precio': {type(precio)}")

# 2. El tipo de la variable cambia. Python ahora infiere que 'precio' es un float
precio = 50.55
print(f"Tipo actual de 'precio': {type(precio)}")

# 3. El tipo cambia de nuevo. Python ahora infiere que 'precio' es una cadena (str)
precio = "Cincuenta Euros"
print(f"Tipo final de 'precio': {type(precio)}")

# %% [markdown]
# ## Gestión de Memoria y Referencias

# %% [markdown]
# En Python **todo es un objeto**. Esto tiene una consecuencia directa en cómo el lenguaje maneja la memoria: las variables en Python no contienen directamente los valores, sino que contienen **referencias** (direcciones de memoria) a los objetos que almacenan esos valores.

# %% [markdown]
# **1. El Operador id() (La Cédula del Objeto)**
#
# Cada objeto que se crea en Python tiene un identificador único en la memoria. Este identificador se puede ver con la función id(). Es como la "cédula de identidad" del objeto.

# %%
a = 10
b = 10
c = 20

# 'a' y 'b' apuntan al mismo objeto inmutable '10' para ahorrar memoria.
print(f"ID de 'a': {id(a)}")
print(f"ID de 'b': {id(b)}")
print(f"¿'a' y 'b' son el mismo objeto? {a is b}") # El operador 'is' comprueba la identidad (ID)

# 'c' es un objeto diferente.
print(f"ID de 'c': {id(c)}")

# %% [markdown]
# **2. Variables como Etiquetas (Referencias)**
# Cuando asignamos un valor a una nueva variable, realmente estamos creando una nueva etiqueta que apunta al mismo objeto en la memoria.

# %% [markdown]
# Cuando asignamos un valor a una nueva variable, realmente estamos creando una nueva etiqueta que apunta al mismo objeto en la memoria.

# %%
lista = ['perro', 'gato', 'pato', 'pez', 'loro']

# %%
len(lista)

# %%
lista[0]

# %%
lista_a = [1, 2, 3]
# 'lista_b' es una nueva etiqueta para el MISMO objeto.
lista_b = lista_a

print(f"ID de lista_a: {id(lista_a)}")
print(f"ID de lista_b: {id(lista_b)}")
print(f"¿Apuntan al mismo objeto? {lista_a is lista_b}")

# Si modificamos el objeto a través de una etiqueta...
lista_a.append(4)

# ...el cambio se refleja en la otra etiqueta, ¡porque es el mismo objeto!
print(f"Lista B después del cambio: {lista_b}")

# %% [markdown]
# **Punto Clave:** Esto es vital para entender por qué modificar una lista o un diccionario en una función afecta a la variable original, mientras que modificar un número o una cadena no lo hace (debido a la inmutabilidad de estos últimos).

# %% [markdown]
# **3. Recolección de Basura (Garbage Collection)**
#
# El hecho de que las variables solo mantengan referencias nos lleva al concepto de **Recolección de Basura** (Garbage Collection).
#
# Cuando un objeto en memoria deja de tener **ninguna referencia** apuntándolo (es decir, ninguna etiqueta lo necesita), Python asume que ese objeto ya no es necesario y lo elimina de la memoria para liberarla. Esto sucede automáticamente.

# %%
x = [10, 20] # El objeto [10, 20] tiene 1 referencia (desde 'x').
y = x        # El objeto [10, 20] ahora tiene 2 referencias (desde 'x' e 'y').

# Eliminamos la etiqueta 'x'. El objeto [10, 20] tiene 1 referencia (desde 'y').
del x
# print(x) # Esto causaría un error NameError porque la etiqueta 'x' ya no existe.

# Eliminamos la etiqueta 'y'. El objeto [10, 20] tiene 0 referencias.
del y

# Python automáticamente elimina el objeto [10, 20] de la memoria (Garbage Collection).

# %% [markdown]
# **Conclusión:** Comprender el manejo de referencias y el Garbage Collection es fundamental para escribir código eficiente y evitar errores comunes al trabajar con estructuras de datos complejas en Python.

# %% [markdown]
# ## Mutabilidad e Inmutabilidad
#
# Esta es la distinción más importante sobre cómo se comportan los diferentes tipos de objetos en Python cuando intentamos modificarlos.

# %% [markdown]
# **1. Objetos Inmutables (Immutable)**
#
# Los objetos **inmutables** no pueden cambiar su valor o su estado después de haber sido creados. Si intentamos "modificarlos", lo que Python hace en realidad es crear un objeto completamente nuevo en una dirección de memoria diferente.
#
# **Tipos Inmutables Comunes:**
# - Números (int, float, complex)
#
# - Cadenas de texto (str)
#
# - Tuplas (tuple)
#
# - Booleanos (bool)

# %%
texto_original = "Hola"
id_original = id(texto_original)
print(f"ID original: {id_original}")

# Intentamos "modificar" la cadena (esto crea una nueva)
texto_original = texto_original + " Mundo"

id_nuevo = id(texto_original)
print(f"ID nuevo:     {id_nuevo}")

# Los IDs son diferentes, lo que prueba que se creó un objeto nuevo.
print(f"¿Son el mismo objeto? {id_original == id_nuevo}")

# %% [markdown]
# **2. Objetos Mutables (Mutable)**
#
# Los objetos **mutables pueden cambiar su contenido o estado** in situ (en el mismo lugar) después de haber sido creados. No se crea un objeto nuevo; el cambio se realiza directamente en la misma dirección de memoria.
#
# **Tipos Mutables Comunes:**
# - Listas (list)
#
# - Diccionarios (dict)
#
# - Conjuntos (set)

# %%
lista = [1, 2, 3]
id_original = id(lista)
print(f"ID original: {id_original}")

# Modificamos la lista *sin* reasignarla, usando un método (append)
lista.append(4)

id_nuevo = id(lista)
print(f"ID nuevo:     {id_nuevo}")

# Los IDs son iguales, lo que prueba que se modificó el objeto existente.
print(f"¿Son el mismo objeto? {id_original == id_nuevo}")
print(f"Contenido modificado: {lista}")

# %% [markdown]
# **🎯 Importancia en la Práctica**
# Esta distinción es crítica en dos escenarios:
#
# 1. **Referencias y Funciones:**
#
# - Si pasas un objeto mutable (como una lista) a una función y lo modificas dentro de ella, el cambio será visible fuera de la función.
#
# - Si pasas un objeto inmutable (como un entero o una cadena) a una función y lo modificas, el cambio no será visible fuera de la función (porque la modificación crea un objeto nuevo dentro de la función, dejando el original intacto).
#
# 2. **Uso en Diccionarios y Conjuntos:**
#
# - En Python, solo los objetos inmutables pueden ser usados como claves en un diccionario (dict) o como elementos en un conjunto (set). Esto se debe a que, para encontrar una clave, su valor no puede cambiar, garantizando que el hash (la huella digital de la clave) sea siempre el mismo.
